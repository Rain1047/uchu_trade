# %%
import pandas as pd
from tvDatafeed import Interval
from backend.data_center.kline_data.kline_data_collector import KlineDataCollector

from backend.strategy_center.atom_strategy.entry_strategy.dbb_entry_strategy import dbb_entry_long_strategy_backtest
# Out:
# market OKX API initialized.
# past_time: 2024-10-24 17:37:18.460755
# 2024-11-23 17:37:18.460982

# %%
tv = KlineDataCollector()
file_abspath = tv.get_abspath(symbol='BTC', interval=Interval.in_daily)
df = pd.read_csv(f"{file_abspath}")

# 确保datetime格式正确
df['datetime'] = pd.to_datetime(df['datetime'])
df = dbb_entry_long_strategy_backtest(df)

# 选择这几个时间点及其前后的数据点以便检查
selected_times = pd.to_datetime([
    "2024-01-04 08:00:00",
    "2024-01-03 08:00:00",
    "2024-01-02 08:00:00"
])

# 获取这些时间点及其前两个时间点的数据
all_needed_data = df[['datetime', 'open', 'close', 'upper_band1']].copy()
print("\n完整的条件检查：")
for dt in selected_times:
    current_row = all_needed_data[all_needed_data['datetime'] == dt]
    if len(current_row) > 0:
        idx = current_row.index[0]
        print(f"\n当前时间: {dt}")
        print(f"当前行:")
        print(f"open < upper_band1: {current_row['open'].iloc[0]} < {current_row['upper_band1'].iloc[0]} = {current_row['open'].iloc[0] < current_row['upper_band1'].iloc[0]}")
        print(f"close > upper_band1: {current_row['close'].iloc[0]} > {current_row['upper_band1'].iloc[0]} = {current_row['close'].iloc[0] > current_row['upper_band1'].iloc[0]}")
        
        # 获取前一行数据
        prev_row1 = all_needed_data.shift(1).loc[idx]
        print(f"\n前一行:")
        print(f"prev_open < prev_upper_band1: {prev_row1['open']} < {prev_row1['upper_band1']} = {prev_row1['open'] < prev_row1['upper_band1']}")
        
        # 获取前两行数据
        prev_row2 = all_needed_data.shift(2).loc[idx]
        print(f"\n前两行:")
        print(f"prev_open_2 < prev_upper_band1_2: {prev_row2['open']} < {prev_row2['upper_band1']} = {prev_row2['open'] < prev_row2['upper_band1']}")
        
        print("\n最终entry_sig值:", df.loc[idx, 'entry_sig'])
        print("-" * 80)
        
df[df['entry_sig'] == 1]
# Out:
# error while signin
# you are using nologin method, data you access may be limited
# Signal Verification:
#
# Time: 2017-09-27 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2017-10-29 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2017-11-15 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2017-11-16 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-01-05 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-02-17 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-03-01 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-03-02 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-04-12 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-07-07 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-07-16 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-07-17 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-09-27 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-10-15 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-11-07 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2018-12-20 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-01-06 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-02-08 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-02-17 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-02-18 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-03-15 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-03-27 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-05-01 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-05-02 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-05-26 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-06-14 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-07-03 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-07-08 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-08-02 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-08-03 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-09-03 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-10-25 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-12-22 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2019-12-29 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-01-06 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-01-27 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-01-28 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-02-18 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-04-01 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-04-02 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-04-18 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-04-23 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-05-14 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-05-30 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-06-10 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-07-08 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-07-21 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-08-15 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-10-08 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-11-30 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-12-15 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2020-12-16 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-01-14 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-02-03 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-03-09 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-04-02 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-04-10 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-05-07 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-05-08 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-06-13 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-07-24 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-08-05 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-08-06 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-08-19 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-08-20 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-09-02 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-09-03 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-10-01 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-10-25 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-11-08 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2021-12-23 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-02-04 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-02-15 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-03-01 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-03-09 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-03-22 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-05-30 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-06-06 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-07-07 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-07-16 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-07-27 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-07-28 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-08-08 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-09-09 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-10-04 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-10-25 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-11-30 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-12-12 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2022-12-13 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-01-04 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-01-06 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-02-15 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-03-13 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-04-10 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-05-28 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-06-20 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-07-03 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-07-13 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-08-08 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-09-18 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-09-28 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-10-16 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-11-09 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-11-19 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-12-21 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2023-12-22 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-01-01 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-02-06 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-02-07 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-02-26 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-04-08 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-05-15 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-06-04 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-07-15 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-07-26 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-08-21 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-10-14 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-10-24 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-10-28 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# Time: 2024-11-06 08:00:00
# Condition 1 (current open < upper_band1): True
# Condition 2 (current close > upper_band1): True
# Condition 3 (prev open < prev upper_band1): True
# Condition 4 (prev_2 open < prev_2 upper_band1): True
#
# 完整的条件检查：
#
# 当前时间: 2024-01-04 08:00:00
# 当前行:
# open < upper_band1: 42845.23 < 43965.73048117387 = True
# close > upper_band1: 44151.1 > 43965.73048117387 = True
#
# 前一行:
# prev_open < prev_upper_band1: 44946.91 < 43851.787710521545 = False
#
# 前两行:
# prev_open_2 < prev_upper_band1_2: 44179.55 < 43860.303526916 = False
#
# 最终entry_sig值: 0
# --------------------------------------------------------------------------------
#
# 当前时间: 2024-01-03 08:00:00
# 当前行:
# open < upper_band1: 44946.91 < 43851.787710521545 = False
# close > upper_band1: 42845.23 > 43851.787710521545 = False
#
# 前一行:
# prev_open < prev_upper_band1: 44179.55 < 43860.303526916 = False
#
# 前两行:
# prev_open_2 < prev_upper_band1_2: 42283.58 < 43632.18135310362 = True
#
# 最终entry_sig值: 0
# --------------------------------------------------------------------------------
#
# 当前时间: 2024-01-02 08:00:00
# 当前行:
# open < upper_band1: 44179.55 < 43860.303526916 = False
# close > upper_band1: 44946.91 > 43860.303526916 = True
#
# 前一行:
# prev_open < prev_upper_band1: 42283.58 < 43632.18135310362 = True
#
# 前两行:
# prev_open_2 < prev_upper_band1_2: 42140.29 < 43491.61422284313 = True
#
# 最终entry_sig值: 0
# --------------------------------------------------------------------------------
#                 datetime           symbol      open      high       low  \
# 41   2017-09-27 08:00:00  Binance:BTCUSDT   3882.36   4249.94   3872.81
# 73   2017-10-29 08:00:00  Binance:BTCUSDT   5709.98   6189.88   5648.01
# 90   2017-11-15 08:00:00  Binance:BTCUSDT   6575.99   7298.00   6575.99
# 91   2017-11-16 08:00:00  Binance:BTCUSDT   7240.14   7940.00   7076.00
# 141  2018-01-05 08:00:00  Binance:BTCUSDT  15059.56  17176.24  14600.00
# ...                  ...              ...       ...       ...       ...
# 2561 2024-08-21 08:00:00  Binance:BTCUSDT  59013.80  61820.93  58783.47
# 2615 2024-10-14 08:00:00  Binance:BTCUSDT  62870.02  66500.00  62457.81
# 2625 2024-10-24 08:00:00  Binance:BTCUSDT  66668.65  68850.00  66510.00
# 2629 2024-10-28 08:00:00  Binance:BTCUSDT  68021.69  70270.00  67618.00
# 2638 2024-11-06 08:00:00  Binance:BTCUSDT  69372.01  76400.00  69298.00
#
#          close         volume        adx     sma10     sma20  ...     ema10  \
# 41     4193.00     628.170966  38.490167   3848.70   3888.99  ...   3886.92
# 73     6169.98    1804.778173  20.934012   5858.82   5670.18  ...   5804.71
# 90     7240.06    1779.605845  26.135709   6725.12   6654.22  ...   6686.01
# 91     7864.50    2331.956750  25.806146   6815.56   6759.00  ...   6900.28
# 141   16960.39   23251.491125  24.262516  14517.19  15084.00  ...  14931.27
# ...        ...            ...        ...       ...       ...  ...       ...
# 2561  61156.03   27983.642200  24.586865  59256.05  59012.64  ...  59528.84
# 2615  66083.99   37669.952220  13.715006  62492.50  62905.12  ...  62957.60
# 2625  68198.28   22589.838770  20.614547  67762.44  65127.47  ...  67093.58
# 2629  69962.21   29046.754590  19.970394  67885.54  66253.10  ...  67713.76
# 2638  75571.99  104126.994787  21.411865  70577.61  69154.87  ...  70296.39
#
#          ema20     ema50    ema100    ema200   upper_band1   lower_band1  \
# 41     3932.95       NaN       NaN       NaN   4159.720922   3618.264078
# 73     5569.72   5043.69       NaN       NaN   6013.860326   5326.499674
# 90     6536.02   5898.92       NaN       NaN   7187.566603   6120.863397
# 91     6662.54   5976.00       NaN       NaN   7313.551031   6204.445969
# 141   14743.56  13117.63  10464.46       NaN  16866.053130  13301.943870
# ...        ...       ...       ...       ...           ...           ...
# 2561  60026.61  61448.42  62161.05  59440.67  61051.281124  56974.007876
# 2615  62533.04  61758.72  61650.58  60161.62  64752.540493  61057.695507
# 2625  65836.64  63738.29  62758.60  60884.97  68006.029353  62248.909647
# 2629  66576.54  64368.14  63159.33  61162.28  68959.415794  63546.783206
# 2638  69005.87  66264.76  64391.85  61978.28  71324.515373  66985.218627
#
#        upper_band2   lower_band2  entry_sig
# 41     4430.449345   3347.535655          1
# 73     6357.540653   4982.819347          1
# 90     7720.918205   5587.511795          1
# 91     7868.103561   5649.893439          1
# 141   18648.107760  11519.889240          1
# ...            ...           ...        ...
# 2561  63089.917748  54935.371252          1
# 2615  66599.962985  59210.273015          1
# 2625  70884.589206  59370.349794          1
# 2629  71665.732087  60840.466913          1
# 2638  73494.163745  64815.570255          1
#
# [120 rows x 23 columns]

# %%
tv = KlineDataCollector()
file_abspath = tv.get_abspath(symbol='BTC', interval=Interval.in_daily)
df = pd.read_csv(f"{file_abspath}")

df = dbb_entry_long_strategy_backtest(df)
df[df['entry_sig'] == 1]
# df
# Out:
# error while signin
# you are using nologin method, data you access may be limited
#                  datetime           symbol      open      high       low  \
# 20    2017-09-06 08:00:00  Binance:BTCUSDT   4366.49   4662.87   4335.26
# 41    2017-09-27 08:00:00  Binance:BTCUSDT   3882.36   4249.94   3872.81
# 49    2017-10-05 08:00:00  Binance:BTCUSDT   4208.59   4355.00   4110.00
# 63    2017-10-19 08:00:00  Binance:BTCUSDT   5513.00   5710.00   5490.26
# 73    2017-10-29 08:00:00  Binance:BTCUSDT   5709.98   6189.88   5648.01
# ...                   ...              ...       ...       ...       ...
# 2588  2024-09-17 08:00:00  Binance:BTCUSDT  58213.99  61320.00  57610.01
# 2597  2024-09-26 08:00:00  Binance:BTCUSDT  63152.01  65839.00  62670.00
# 2615  2024-10-14 08:00:00  Binance:BTCUSDT  62870.02  66500.00  62457.81
# 2625  2024-10-24 08:00:00  Binance:BTCUSDT  66668.65  68850.00  66510.00
# 2629  2024-10-28 08:00:00  Binance:BTCUSDT  68021.69  70270.00  67618.00
#
#          close        volume        adx     sma10     sma20  ...     ema20  \
# 20     4619.77    807.363726        NaN   4515.67   4345.27  ...   4356.28
# 41     4193.00    628.170966  38.490167   3848.70   3888.99  ...   3932.95
# 49     4292.43    779.138638  25.575529   4237.25   4009.96  ...   4130.07
# 63     5683.90   1881.722107  27.223155   5481.54   4949.12  ...   5077.02
# 73     6169.98   1804.778173  20.934012   5858.82   5670.18  ...   5569.72
# ...        ...           ...        ...       ...       ...  ...       ...
# 2588  60313.99  33116.258780  17.523489  58316.93  57841.14  ...  58551.04
# 2597  65173.99  28373.305930  20.381693  63107.94  60404.78  ...  61547.21
# 2615  66083.99  37669.952220  13.715006  62492.50  62905.12  ...  62533.04
# 2625  68198.28  22589.838770  20.614547  67762.44  65127.47  ...  65836.64
# 2629  69962.21  29046.754590  19.970394  67885.54  66253.10  ...  66576.54
#
#          ema50    ema100    ema200   upper_band1   lower_band1   upper_band2  \
# 20         NaN       NaN       NaN   4579.140635   4111.406365   4813.007771
# 41         NaN       NaN       NaN   4159.720922   3618.264078   4430.449345
# 49     4159.18       NaN       NaN   4278.509220   3741.407780   4547.059940
# 63     4643.87       NaN       NaN   5550.085326   4348.153674   6151.051152
# 73     5043.69       NaN       NaN   6013.860326   5326.499674   6357.540653
# ...        ...       ...       ...           ...           ...           ...
# 2588  59570.53  60734.53  59295.48  59686.842991  55995.428009  61532.550482
# 2597  60755.87  61182.64  59651.90  63554.605522  57254.951478  66704.432544
# 2615  61758.72  61650.58  60161.62  64752.540493  61057.695507  66599.962985
# 2625  63738.29  62758.60  60884.97  68006.029353  62248.909647  70884.589206
# 2629  64368.14  63159.33  61162.28  68959.415794  63546.783206  71665.732087
#
#        lower_band2  entry_sig  entry_price
# 20     3877.539229          1      4366.49
# 41     3347.535655          1      3882.36
# 49     3472.857060          1      4208.59
# 63     3747.187848          1      5513.00
# 73     4982.819347          1      5709.98
# ...            ...        ...          ...
# 2588  54149.720518          1     58213.99
# 2597  54105.124456          1     63152.01
# 2615  59210.273015          1     62870.02
# 2625  59370.349794          1     66668.65
# 2629  60840.466913          1     68021.69
#
# [164 rows x 24 columns]

# %%
df[df['datetime'].isin(["2024-01-04 08:00:00", "2024-01-03 08:00:00", "2024-01-02 08:00:00"])][['datetime','open','close','upper_band1','upper_band2','entry_sig']]
# Out:
#                  datetime      open     close   upper_band1   upper_band2  \
# 2329  2024-01-02 08:00:00  44179.55  44946.91  43860.303527  44748.737054
# 2330  2024-01-03 08:00:00  44946.91  42845.23  43851.787711  44740.556921
# 2331  2024-01-04 08:00:00  42845.23  44151.10  43965.730481  44857.902462
#
#       entry_sig
# 2329          0
# 2330          0
# 2331          1
